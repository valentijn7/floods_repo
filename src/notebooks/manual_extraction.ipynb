# %% [markdown]
# # **Processing manually extracted files from the data bucket -- discontinued**

# %% [markdown]
# Here, we import the .json-formatted data and, as a first plan, convert it to a pandas DataFrame. Later, tensors might be useful considering the high-dimensionality of the data, but it may be overkill for now

# %% [markdown]
# First, we import relevant packages

# %%
import os
from typing import List, Dict, Any, Tuple
from datetime import datetime
from exceptions import MissingKeyError

import json
import pandas as pd

# %% [markdown]
# For now, we only have some manually downloaded files from the Google Cloud bucket. Thus, we only access one folder. Later, we'll add an automated parsing function

# %%
def read_file(file_path : str) -> Dict:
    """
    Reads a .json file and return its content as a dictionary

    :param file_path: path to the file
    :return: dictionary with the content of the file
    """
    try:
        with open(file_path, 'r') as file:
            data = json.load(file)
            
            # Add the file path to the data, so we can track the source of the data later
            data['path'] = file_path
            return data
    except FileNotFoundError:
        print(f"File not found: {file_path}")
        return {}
    except json.JSONDecodeError:
        print(f"Error decoding JSON from file: {file_path}")
        return {}
    

def get_file_contents(file_paths : List[str]) -> List[Dict]:
    """
    Reads the content of the files and returns it as a list of dictionaries

    :param file_paths: list of paths to the files
    :return: list of dictionaries with the content of the files
    """
    return [read_file(file_path) for file_path in file_paths]


def generate_path(folder_path: str, file_name: str) -> str:
    """
    Generates the path to the file

    :param folder_path: path to the folder
    :param file_name: name of the file
    :return: path to the file
    """
    return os.path.join(folder_path, file_name)


def generate_file_paths(folder_path: str, file_names: List[str]) -> List[str]:
    """
    Generates the paths to the files

    :param folder_path: path to the folder
    :param file_names: list of file names
    :return: list of paths to the files
    """
    return [generate_path(folder_path, file_name) for file_name in file_names]


def get_file_names(folder_path : str) -> List[str]:
    """
    Return a list of filenames within given directory

    :param file_path: path to the directory
    :return: list of filenames
    """
    try:
        return os.listdir(folder_path)
    except FileNotFoundError:
        print(f"Directory not found: {folder_path}")
        return []


def get_file_dictionaries(folder_path : str) -> List[Dict]:
    """
    Reads the content of the files and returns it as a list of dictionaries

    :param folder_path: path to the directory containing the files
    :return: list of dictionaries with the content of the files
    """
    return get_file_contents(generate_file_paths(folder_path, get_file_names(folder_path)))

# %% [markdown]
# Now, we only need a path to a folder and we can extract all .json files in there and convert them to a list of dictionaries

# %%
path_manual_data = "../../data/floods-data_manual/2022/01/25/00/00"
dicts_manual_data = get_file_dictionaries(path_manual_data)

print(type(dicts_manual_data))
print(len(dicts_manual_data))
print(dicts_manual_data[0])
# Out:
# <class 'list'>
# 423
# {'apiVersion': '1.0', 'alertMetadata': {'district': 'SRINAGAR', 'gaugeStationName': 'Ram Munshi Bagh', 'stationId': '005-jhelum', 'publisherName': 'IBO, CWC, Chandigarh', 'river': 'Jhelum', 'state': 'Jammu & Kashmir', 'waterLevelThresholds': {'warningLevel': 1585.53, 'dangerLevel': 1586.45, 'extremeDangerLevel': 1588.99}}, 'issueTimestampSeconds': '1643070287', 'expirationTimestampSeconds': '1643243087', 'hasFlooding': False, 'path': '../../data/floods-data_manual/2022/01/25/00/00\\2022_01_25_00_00_001294ea063c4465b2cef91bed6acf1c_001294ea063c4465b2cef91bed6acf1c.json'}

# %% [markdown]
# Next, we extract the dictionaries into a pandas DataFrame

# %%
def check_required_keys(d: Dict, file: str, required_keys: List[str]) -> None:
    """
    Checks if the required keys are present in the dictionary

    :param d: Dictionary to check
    :param file: Filename or path for error reporting
    :param required_keys: List of required keys
    :raises MissingKeyError: If any required key is missing
    """
    for key in required_keys:
        if key not in d:
            raise MissingKeyError(key, file)


def extract_dictionary_data(d: Dict) -> Dict:
    """
    Extracts the data from the dictionary

    :param dictionary: dictionary with the data
    :return: Transformed dictionary
    """
    alert_metadata = d.get('alertMetadata', {})
    water_level_thresholds = alert_metadata.get('waterLevelThresholds', {})

    check_required_keys(d, d['path'], ['issueTimestampSeconds', 'expirationTimestampSeconds', 'hasFlooding'])
    check_required_keys(alert_metadata, d['path'], ['district', 'gaugeStationName', 'stationId', 'publisherName', 'river', 'state'])
    check_required_keys(water_level_thresholds, d['path'], ['warningLevel', 'dangerLevel', 'extremeDangerLevel'])

    # If all is well, we can return the dictionary. Else, the Exception will be raised
    return {
        
        # Convert Unix timestamp to DateTime
        'DateTime': datetime.fromtimestamp(int(d['issueTimestampSeconds'])),
        'district': alert_metadata['district'],
        'gaugeStationName': alert_metadata['gaugeStationName'],
        'stationId': alert_metadata['stationId'],
        'publisherName': alert_metadata['publisherName'],
        'river': alert_metadata['river'],
        'state': alert_metadata['state'],
        'warningLevel': alert_metadata['waterLevelThresholds']['warningLevel'],
        'dangerLevel': alert_metadata['waterLevelThresholds']['dangerLevel'],
        'extremeDangerLevel': alert_metadata['waterLevelThresholds']['extremeDangerLevel'],

        # Same conversion for expiration timestamp
        'expirationTimestamp': datetime.fromtimestamp(int(d['expirationTimestampSeconds'])),
        'hasFlooding': d['hasFlooding']
    }


def create_dataframe_from_dicts(dicts: List[Dict]) -> pd.DataFrame:
    """
    Creates a DataFrame from a list of dictionaries and sets a DateTime index

    :param dicts: List of dictionaries
    :return: DataFrame with DateTime index
    """
    data = []
    for d in dicts:
        try:
            data.append(extract_dictionary_data(d))
        except MissingKeyError as e:
            print(e)
    
    return pd.DataFrame(data)


def convert_columns_to_string(df):
    """
    Converts all columns of type 'object' in the DataFrame to string

    :param df: DataFrame to convert
    :return: Modified DataFrame
    """
    for column in df.columns:
        if df[column].dtype == 'object':
            df[column] = df[column].astype('str')
    return df


def modify_column_strings(s: str) -> str:
    """
    Capitalizes each alphabetic sequence in a string. Non-alphabetic
    characters are treated as delimiters. Newlines are replaced with
    spaces, and spaces are added before and after each slash '/'.

    :param s: Input string
    :return: Capitalized string
    """
    result = []
    capitalize_next = True

    for char in s:
        if char.isalpha():
            if capitalize_next:
                result.append(char.upper())
                capitalize_next = False
            else:
                result.append(char.lower())
        else:
            if char == '\n':
                result.append(' ')
            elif char == '/':
                result.append(' / ')
            else:
                result.append(char)
            capitalize_next = True

    return ''.join(result)


def modify_string_columns(df: pd.DataFrame, cols: str) -> pd.DataFrame:
    """
    Converts all columns of type 'object' (strings) in the DataFrame to lowercase

    :param df: DataFrame to convert
    :return: Modified DataFrame
    """
    for column in df.columns:
        print(df[column].dtype)
        if column in cols:
            df[column] = df[column].astype(str).apply(modify_column_strings)
    return df


def tidy_up_dataframe(df: pd.DataFrame) -> pd.DataFrame:
    """
    Tidies up the DataFrame by doing various modifications

    :param df: DataFrame to tidy up
    :return: Tidied up DataFrame
    """
    # These are the columns we want to convert to lowercase because of
    # inconsistencies in their capitalization
    to_be_modified_string_columns = [
        'district',
        'gaugeStationName',
        'river',
        'state'
    ]

    df.set_index('DateTime', inplace = True)
    df.sort_index(inplace = True)
    # df = convert_columns_to_string(df)
    df = modify_string_columns(df, to_be_modified_string_columns)

    return df

# %%
df_manual_data = create_dataframe_from_dicts(dicts_manual_data)
# Out:
# Missing key 'state' in file '../../data/floods-data_manual/2022/01/25/00/00\2022_01_25_00_00_01c33b58fa4a4ccf8c994ea267a6acc7_01c33b58fa4a4ccf8c994ea267a6acc7.json'
# Missing key 'publisherName' in file '../../data/floods-data_manual/2022/01/25/00/00\2022_01_25_00_00_03096dd7ff66423f86f064ec650e2aae_03096dd7ff66423f86f064ec650e2aae.json'
# Missing key 'publisherName' in file '../../data/floods-data_manual/2022/01/25/00/00\2022_01_25_00_00_04371a70d79e40439a076b4ce47ee995_04371a70d79e40439a076b4ce47ee995.json'
# Missing key 'extremeDangerLevel' in file '../../data/floods-data_manual/2022/01/25/00/00\2022_01_25_00_00_045a6d8b77a44ce68acca83057151a98_045a6d8b77a44ce68acca83057151a98.json'
# Missing key 'district' in file '../../data/floods-data_manual/2022/01/25/00/00\2022_01_25_00_00_0a1729335b954a7c8d36181d3f929fad_0a1729335b954a7c8d36181d3f929fad.json'
# Missing key 'publisherName' in file '../../data/floods-data_manual/2022/01/25/00/00\2022_01_25_00_00_0afbbf7bfdce485bafcf24056819ac1a_0afbbf7bfdce485bafcf24056819ac1a.json'
# Missing key 'district' in file '../../data/floods-data_manual/2022/01/25/00/00\2022_01_25_00_00_0cf6eb07f1334242b56a99e075609151_0cf6eb07f1334242b56a99e075609151.json'
# Missing key 'extremeDangerLevel' in file '../../data/floods-data_manual/2022/01/25/00/00\2022_01_25_00_00_1089108b710c4d30bb9d8f8ad182fb45_1089108b710c4d30bb9d8f8ad182fb45.json'
# Missing key 'district' in file '../../data/floods-data_manual/2022/01/25/00/00\2022_01_25_00_00_1267e27f725949bdb2685d27e3074a57_1267e27f725949bdb2685d27e3074a57.json'
# Missing key 'district' in file '../../data/floods-data_manual/2022/01/25/00/00\2022_01_25_00_00_141d8e974f98427db631e71141cede30_141d8e974f98427db631e71141cede30.json'
# Missing key 'state' in file '../../data/floods-data_manual/2022/01/25/00/00\2022_01_25_00_00_15f4992d17fd4a779a6ec6281996cb01_15f4992d17fd4a779a6ec6281996cb01.json'
# Missing key 'district' in file '../../data/floods-data_manual/2022/01/25/00/00\2022_01_25_00_00_1651e892613a4ec4ab5276ccad069cfc_1651e892613a4ec4ab5276ccad069cfc.json'
# Missing key 'state' in file '../../data/floods-data_manual/2022/01/25/00/00\2022_01_25_00_00_1652366fb1cb4099a8f8461cc4221c14_1652366fb1cb4099a8f8461cc4221c14.json'
# Missing key 'district' in file '../../data/floods-data_manual/2022/01/25/00/00\2022_01_25_00_00_1a0ea2d27dec4c2698f98fc6d9724737_1a0ea2d27dec4c2698f98fc6d9724737.json'
# Missing key 'state' in file '../../data/floods-data_manual/2022/01/25/00/00\2022_01_25_00_00_1c09d8a559a147cebeee979d09d05ebd_1c09d8a559a147cebeee979d09d05ebd.json'
# Missing key 'state' in file '../../data/floods-data_manual/2022/01/25/00/00\2022_01_25_00_00_1c48a1d3fba54efeac78e1dfe66ef9ad_1c48a1d3fba54efeac78e1dfe66ef9ad.json'
# Missing key 'state' in file '../../data/floods-data_manual/2022/01/25/00/00\2022_01_25_00_00_221328b918c24e29b200e79c32af9847_221328b918c24e29b200e79c32af9847.json'
# Missing key 'district' in file '../../data/floods-data_manual/2022/01/25/00/00\2022_01_25_00_00_22ee61ac8ec8441a80894222a6fe9dd7_22ee61ac8ec8441a80894222a6fe9dd7.json'
# Missing key 'district' in file '../../data/floods-data_manual/2022/01/25/00/00\2022_01_25_00_00_24d770ad4d1341d09d5e2a1969bc7e90_24d770ad4d1341d09d5e2a1969bc7e90.json'
# Missing key 'district' in file '../../data/floods-data_manual/2022/01/25/00/00\2022_01_25_00_00_25f698f13a3e4be9aadecc9d23bf5dca_25f698f13a3e4be9aadecc9d23bf5dca.json'
# Missing key 'district' in file '../../data/floods-data_manual/2022/01/25/00/00\2022_01_25_00_00_261e839c17f54ab5b584bb65bd86a04c_261e839c17f54ab5b584bb65bd86a04c.json'
# Missing key 'publisherName' in file '../../data/floods-data_manual/2022/01/25/00/00\2022_01_25_00_00_2761cdab0a754f0797cbcd284f94f307_2761cdab0a754f0797cbcd284f94f307.json'
# Missing key 'district' in file '../../data/floods-data_manual/2022/01/25/00/00\2022_01_25_00_00_27b3aac63fe14c2680761e47723a6cfc_27b3aac63fe14c2680761e47723a6cfc.json'
# Missing key 'district' in file '../../data/floods-data_manual/2022/01/25/00/00\2022_01_25_00_00_2a22da37ceba43529b360200724bf083_2a22da37ceba43529b360200724bf083.json'
# Missing key 'state' in file '../../data/floods-data_manual/2022/01/25/00/00\2022_01_25_00_00_2aa46900105c4a27affc7122b91f4c4d_2aa46900105c4a27affc7122b91f4c4d.json'
# Missing key 'district' in file '../../data/floods-data_manual/2022/01/25/00/00\2022_01_25_00_00_2dc07bbacac54d69af23513d684de8f6_2dc07bbacac54d69af23513d684de8f6.json'
# Missing key 'state' in file '../../data/floods-data_manual/2022/01/25/00/00\2022_01_25_00_00_2ea3716994a44a0a8b48465fe039dc8f_2ea3716994a44a0a8b48465fe039dc8f.json'
# Missing key 'state' in file '../../data/floods-data_manual/2022/01/25/00/00\2022_01_25_00_00_34974fa110e14b9fa2a8ecf9d56c07b0_34974fa110e14b9fa2a8ecf9d56c07b0.json'
# Missing key 'district' in file '../../data/floods-data_manual/2022/01/25/00/00\2022_01_25_00_00_3570e3db9dc249a6bbf952f9ff0ad01e_3570e3db9dc249a6bbf952f9ff0ad01e.json'
# Missing key 'publisherName' in file '../../data/floods-data_manual/2022/01/25/00/00\2022_01_25_00_00_37c89ef091734fd79b90c6737c0475bc_37c89ef091734fd79b90c6737c0475bc.json'
# Missing key 'district' in file '../../data/floods-data_manual/2022/01/25/00/00\2022_01_25_00_00_38b42b4aee2a461181a1806e85cff2f5_38b42b4aee2a461181a1806e85cff2f5.json'
# Missing key 'publisherName' in file '../../data/floods-data_manual/2022/01/25/00/00\2022_01_25_00_00_3948d80bd8cf4a9ba77decfe4c23fed3_3948d80bd8cf4a9ba77decfe4c23fed3.json'
# Missing key 'district' in file '../../data/floods-data_manual/2022/01/25/00/00\2022_01_25_00_00_39f9b72fdf9c47afb4f854c0c6a80440_39f9b72fdf9c47afb4f854c0c6a80440.json'
# Missing key 'state' in file '../../data/floods-data_manual/2022/01/25/00/00\2022_01_25_00_00_3b71dce38c7a4294a5deed23ba5f3a1c_3b71dce38c7a4294a5deed23ba5f3a1c.json'
# Missing key 'publisherName' in file '../../data/floods-data_manual/2022/01/25/00/00\2022_01_25_00_00_3bcfa1c2380a465a9bea4cf992d2a467_3bcfa1c2380a465a9bea4cf992d2a467.json'
# Missing key 'district' in file '../../data/floods-data_manual/2022/01/25/00/00\2022_01_25_00_00_3bec52571c0e415aa14a79e1c35a0c6d_3bec52571c0e415aa14a79e1c35a0c6d.json'
# Missing key 'district' in file '../../data/floods-data_manual/2022/01/25/00/00\2022_01_25_00_00_3c8df9a67f3e402ea79de860ac727b75_3c8df9a67f3e402ea79de860ac727b75.json'
# Missing key 'publisherName' in file '../../data/floods-data_manual/2022/01/25/00/00\2022_01_25_00_00_3f078be80d2f4034b593760631fbbd70_3f078be80d2f4034b593760631fbbd70.json'
# Missing key 'publisherName' in file '../../data/floods-data_manual/2022/01/25/00/00\2022_01_25_00_00_3f92b3233c884225a4cd7323bc49d9fa_3f92b3233c884225a4cd7323bc49d9fa.json'
# Missing key 'district' in file '../../data/floods-data_manual/2022/01/25/00/00\2022_01_25_00_00_40d74ce5d0fa4030b22e403d76b15adb_40d74ce5d0fa4030b22e403d76b15adb.json'
# Missing key 'district' in file '../../data/floods-data_manual/2022/01/25/00/00\2022_01_25_00_00_42d9711fe2c7418c81eeca2356d9542a_42d9711fe2c7418c81eeca2356d9542a.json'
# Missing key 'district' in file '../../data/floods-data_manual/2022/01/25/00/00\2022_01_25_00_00_440a8d3a9041411fadca5248b990bf50_440a8d3a9041411fadca5248b990bf50.json'
# Missing key 'district' in file '../../data/floods-data_manual/2022/01/25/00/00\2022_01_25_00_00_4ad5c4dda1944abe8917678a10ca9dd0_4ad5c4dda1944abe8917678a10ca9dd0.json'
# Missing key 'publisherName' in file '../../data/floods-data_manual/2022/01/25/00/00\2022_01_25_00_00_4d9972c038054bbb8813b30120cf16e9_4d9972c038054bbb8813b30120cf16e9.json'
# Missing key 'extremeDangerLevel' in file '../../data/floods-data_manual/2022/01/25/00/00\2022_01_25_00_00_4eed4aa28c2346b7b6352a29af445689_4eed4aa28c2346b7b6352a29af445689.json'
# Missing key 'district' in file '../../data/floods-data_manual/2022/01/25/00/00\2022_01_25_00_00_4fa3550cd6354ff48160ca99ed3d87d5_4fa3550cd6354ff48160ca99ed3d87d5.json'
# Missing key 'publisherName' in file '../../data/floods-data_manual/2022/01/25/00/00\2022_01_25_00_00_586d98086d7640d986889deed6bab40f_586d98086d7640d986889deed6bab40f.json'
# Missing key 'publisherName' in file '../../data/floods-data_manual/2022/01/25/00/00\2022_01_25_00_00_5936191c75e64df6b5982b1424ce8fd5_5936191c75e64df6b5982b1424ce8fd5.json'
# Missing key 'publisherName' in file '../../data/floods-data_manual/2022/01/25/00/00\2022_01_25_00_00_59726322f9324a68858b895c0000637d_59726322f9324a68858b895c0000637d.json'
# Missing key 'district' in file '../../data/floods-data_manual/2022/01/25/00/00\2022_01_25_00_00_59e1381beb624d5392b37d8361d6a5af_59e1381beb624d5392b37d8361d6a5af.json'
# Missing key 'extremeDangerLevel' in file '../../data/floods-data_manual/2022/01/25/00/00\2022_01_25_00_00_5f2d8b5cdd394f649974ce8f4f846fc4_5f2d8b5cdd394f649974ce8f4f846fc4.json'
# Missing key 'state' in file '../../data/floods-data_manual/2022/01/25/00/00\2022_01_25_00_00_5f6d8b0f5c764785a33a87a23b990067_5f6d8b0f5c764785a33a87a23b990067.json'
# Missing key 'state' in file '../../data/floods-data_manual/2022/01/25/00/00\2022_01_25_00_00_5fad9e3e11734a2488c0a547f136baf8_5fad9e3e11734a2488c0a547f136baf8.json'
# Missing key 'district' in file '../../data/floods-data_manual/2022/01/25/00/00\2022_01_25_00_00_61340b32db534c7e9dc330ab059fcf34_61340b32db534c7e9dc330ab059fcf34.json'
# Missing key 'district' in file '../../data/floods-data_manual/2022/01/25/00/00\2022_01_25_00_00_64fcbb863c924670888fb70f1678b4f5_64fcbb863c924670888fb70f1678b4f5.json'
# Missing key 'district' in file '../../data/floods-data_manual/2022/01/25/00/00\2022_01_25_00_00_658b477471ff4b5bbdbe40066fd1a1bd_658b477471ff4b5bbdbe40066fd1a1bd.json'
# Missing key 'district' in file '../../data/floods-data_manual/2022/01/25/00/00\2022_01_25_00_00_68a2f7f8147e43debdcc4a8644c02ce1_68a2f7f8147e43debdcc4a8644c02ce1.json'
# Missing key 'publisherName' in file '../../data/floods-data_manual/2022/01/25/00/00\2022_01_25_00_00_715a7a6c172242e8a8a92720d896f82d_715a7a6c172242e8a8a92720d896f82d.json'
# Missing key 'publisherName' in file '../../data/floods-data_manual/2022/01/25/00/00\2022_01_25_00_00_73d4f49a6bb649bbb35144c9467e30f3_73d4f49a6bb649bbb35144c9467e30f3.json'
# Missing key 'publisherName' in file '../../data/floods-data_manual/2022/01/25/00/00\2022_01_25_00_00_74ee236c7f374866a43d1006f6e51b6c_74ee236c7f374866a43d1006f6e51b6c.json'
# Missing key 'state' in file '../../data/floods-data_manual/2022/01/25/00/00\2022_01_25_00_00_7608b6b4efd94e8e9dd946aa4e653b19_7608b6b4efd94e8e9dd946aa4e653b19.json'
# Missing key 'district' in file '../../data/floods-data_manual/2022/01/25/00/00\2022_01_25_00_00_773201dca7f44d14a45880a008654f0f_773201dca7f44d14a45880a008654f0f.json'
# Missing key 'district' in file '../../data/floods-data_manual/2022/01/25/00/00\2022_01_25_00_00_77e48e23afa94c278be1947927ab2bbc_77e48e23afa94c278be1947927ab2bbc.json'
# Missing key 'district' in file '../../data/floods-data_manual/2022/01/25/00/00\2022_01_25_00_00_78e8bebc443b44d8920a548f22683505_78e8bebc443b44d8920a548f22683505.json'
# Missing key 'district' in file '../../data/floods-data_manual/2022/01/25/00/00\2022_01_25_00_00_79644c48489d43c583b5278fc6a89ff5_79644c48489d43c583b5278fc6a89ff5.json'
# Missing key 'district' in file '../../data/floods-data_manual/2022/01/25/00/00\2022_01_25_00_00_7980e5b82637473b816858a36f4c4e48_7980e5b82637473b816858a36f4c4e48.json'
# Missing key 'district' in file '../../data/floods-data_manual/2022/01/25/00/00\2022_01_25_00_00_7ebc05ff273e44c48863d31811e19e3c_7ebc05ff273e44c48863d31811e19e3c.json'
# Missing key 'district' in file '../../data/floods-data_manual/2022/01/25/00/00\2022_01_25_00_00_7ff3227452d14533b5e9a25888ba31b3_7ff3227452d14533b5e9a25888ba31b3.json'
# Missing key 'publisherName' in file '../../data/floods-data_manual/2022/01/25/00/00\2022_01_25_00_00_812752fb906b4a858df1122313a3692a_812752fb906b4a858df1122313a3692a.json'
# Missing key 'district' in file '../../data/floods-data_manual/2022/01/25/00/00\2022_01_25_00_00_8276750af41f4f48a024fcc4a12d5401_8276750af41f4f48a024fcc4a12d5401.json'
# Missing key 'district' in file '../../data/floods-data_manual/2022/01/25/00/00\2022_01_25_00_00_8648a4ae63034a118d0bd151ccf1a13f_8648a4ae63034a118d0bd151ccf1a13f.json'
# Missing key 'publisherName' in file '../../data/floods-data_manual/2022/01/25/00/00\2022_01_25_00_00_871bec764c9a4865a7249796b31dd866_871bec764c9a4865a7249796b31dd866.json'
# Missing key 'district' in file '../../data/floods-data_manual/2022/01/25/00/00\2022_01_25_00_00_88e956938ec348daac74961d26bf8b66_88e956938ec348daac74961d26bf8b66.json'
# Missing key 'state' in file '../../data/floods-data_manual/2022/01/25/00/00\2022_01_25_00_00_89b834c3fa1d4a7393d5838dc6e74411_89b834c3fa1d4a7393d5838dc6e74411.json'
# Missing key 'district' in file '../../data/floods-data_manual/2022/01/25/00/00\2022_01_25_00_00_8a499afea03146e3a89a4d0fd5a7c8d7_8a499afea03146e3a89a4d0fd5a7c8d7.json'
# Missing key 'state' in file '../../data/floods-data_manual/2022/01/25/00/00\2022_01_25_00_00_8bb3890fd320414697ccf65ce60f60c8_8bb3890fd320414697ccf65ce60f60c8.json'
# Missing key 'district' in file '../../data/floods-data_manual/2022/01/25/00/00\2022_01_25_00_00_8c042d9190754f778cb567e045c079b1_8c042d9190754f778cb567e045c079b1.json'
# Missing key 'district' in file '../../data/floods-data_manual/2022/01/25/00/00\2022_01_25_00_00_8d87c2e1cd2840a48c7f12eff09ab6d7_8d87c2e1cd2840a48c7f12eff09ab6d7.json'
# Missing key 'state' in file '../../data/floods-data_manual/2022/01/25/00/00\2022_01_25_00_00_8dc579e61c94446fb0cf4fe3b658a317_8dc579e61c94446fb0cf4fe3b658a317.json'
# Missing key 'district' in file '../../data/floods-data_manual/2022/01/25/00/00\2022_01_25_00_00_8e0b62777966481faf68b217011a18df_8e0b62777966481faf68b217011a18df.json'
# Missing key 'publisherName' in file '../../data/floods-data_manual/2022/01/25/00/00\2022_01_25_00_00_8e1dcb6f0be442b18298818aae0cdb56_8e1dcb6f0be442b18298818aae0cdb56.json'
# Missing key 'publisherName' in file '../../data/floods-data_manual/2022/01/25/00/00\2022_01_25_00_00_90b25a8908ed40f3a065d4c3559d1033_90b25a8908ed40f3a065d4c3559d1033.json'
# Missing key 'publisherName' in file '../../data/floods-data_manual/2022/01/25/00/00\2022_01_25_00_00_92f9477cd83040cba6b11d92317245eb_92f9477cd83040cba6b11d92317245eb.json'
# Missing key 'state' in file '../../data/floods-data_manual/2022/01/25/00/00\2022_01_25_00_00_95202dab29704b51be8d643f101b8583_95202dab29704b51be8d643f101b8583.json'
# Missing key 'district' in file '../../data/floods-data_manual/2022/01/25/00/00\2022_01_25_00_00_95797993539f4c1dabb1e06cac48f6ac_95797993539f4c1dabb1e06cac48f6ac.json'
# Missing key 'state' in file '../../data/floods-data_manual/2022/01/25/00/00\2022_01_25_00_00_95f269758d564897adaa70593301e365_95f269758d564897adaa70593301e365.json'
# Missing key 'extremeDangerLevel' in file '../../data/floods-data_manual/2022/01/25/00/00\2022_01_25_00_00_96ef9b29dca24a90986da1cdf3f118c2_96ef9b29dca24a90986da1cdf3f118c2.json'
# Missing key 'district' in file '../../data/floods-data_manual/2022/01/25/00/00\2022_01_25_00_00_97e54d801bc54438858199e7a7a800e1_97e54d801bc54438858199e7a7a800e1.json'
# Missing key 'state' in file '../../data/floods-data_manual/2022/01/25/00/00\2022_01_25_00_00_9a387ed3224043f5bbb36845b45fc922_9a387ed3224043f5bbb36845b45fc922.json'
# Missing key 'publisherName' in file '../../data/floods-data_manual/2022/01/25/00/00\2022_01_25_00_00_9a4d85b8aa7b48d6945aedbd11eb6f1d_9a4d85b8aa7b48d6945aedbd11eb6f1d.json'
# Missing key 'district' in file '../../data/floods-data_manual/2022/01/25/00/00\2022_01_25_00_00_9a7ed67e08284f7dba242249104a6cfd_9a7ed67e08284f7dba242249104a6cfd.json'
# Missing key 'district' in file '../../data/floods-data_manual/2022/01/25/00/00\2022_01_25_00_00_9bddaa6f9d9b4d8c86291d4dc0b4d927_9bddaa6f9d9b4d8c86291d4dc0b4d927.json'
# Missing key 'district' in file '../../data/floods-data_manual/2022/01/25/00/00\2022_01_25_00_00_9ca8d579a23f499bb5ef8cbd4e7665a1_9ca8d579a23f499bb5ef8cbd4e7665a1.json'
# Missing key 'district' in file '../../data/floods-data_manual/2022/01/25/00/00\2022_01_25_00_00_9e7a2fa174f449038352b49e8b0bcf31_9e7a2fa174f449038352b49e8b0bcf31.json'
# Missing key 'state' in file '../../data/floods-data_manual/2022/01/25/00/00\2022_01_25_00_00_9e9300a687444a23b6b1df7c4e4c05b2_9e9300a687444a23b6b1df7c4e4c05b2.json'
# Missing key 'state' in file '../../data/floods-data_manual/2022/01/25/00/00\2022_01_25_00_00_9f5c68228843440bb559866d47848aac_9f5c68228843440bb559866d47848aac.json'
# Missing key 'district' in file '../../data/floods-data_manual/2022/01/25/00/00\2022_01_25_00_00_9ff1fbbcbb064988a7a9457505f56038_9ff1fbbcbb064988a7a9457505f56038.json'
# Missing key 'state' in file '../../data/floods-data_manual/2022/01/25/00/00\2022_01_25_00_00_a041b509ff874a45acb668af5ef67d38_a041b509ff874a45acb668af5ef67d38.json'
# Missing key 'state' in file '../../data/floods-data_manual/2022/01/25/00/00\2022_01_25_00_00_a1d10be16a0a422d854c09e56e43c39c_a1d10be16a0a422d854c09e56e43c39c.json'
# Missing key 'district' in file '../../data/floods-data_manual/2022/01/25/00/00\2022_01_25_00_00_a267144e11344d23b63a7e027b1cd6e5_a267144e11344d23b63a7e027b1cd6e5.json'
# Missing key 'publisherName' in file '../../data/floods-data_manual/2022/01/25/00/00\2022_01_25_00_00_a4413ed5693342808df0a47d77998bd8_a4413ed5693342808df0a47d77998bd8.json'
# Missing key 'state' in file '../../data/floods-data_manual/2022/01/25/00/00\2022_01_25_00_00_a5e4833d329740a1835685c00ab40888_a5e4833d329740a1835685c00ab40888.json'
# Missing key 'state' in file '../../data/floods-data_manual/2022/01/25/00/00\2022_01_25_00_00_a5ebdcdb08104beda30fda298ae267db_a5ebdcdb08104beda30fda298ae267db.json'
# Missing key 'district' in file '../../data/floods-data_manual/2022/01/25/00/00\2022_01_25_00_00_abf0b26c638e45e0950bb7def361e6d9_abf0b26c638e45e0950bb7def361e6d9.json'
# Missing key 'district' in file '../../data/floods-data_manual/2022/01/25/00/00\2022_01_25_00_00_acfd63be3cec4518afd390eeb694a4c3_acfd63be3cec4518afd390eeb694a4c3.json'
# Missing key 'district' in file '../../data/floods-data_manual/2022/01/25/00/00\2022_01_25_00_00_b02c5df7920949d2aed1027d6187bb0c_b02c5df7920949d2aed1027d6187bb0c.json'
# Missing key 'state' in file '../../data/floods-data_manual/2022/01/25/00/00\2022_01_25_00_00_b31f04b7c3e5461a86fbe0c8136050f6_b31f04b7c3e5461a86fbe0c8136050f6.json'
# Missing key 'publisherName' in file '../../data/floods-data_manual/2022/01/25/00/00\2022_01_25_00_00_b3ccb9cf4b4442af8af324e135091fa1_b3ccb9cf4b4442af8af324e135091fa1.json'
# Missing key 'district' in file '../../data/floods-data_manual/2022/01/25/00/00\2022_01_25_00_00_b3faaff0f3574029b4dc5f6ff9369218_b3faaff0f3574029b4dc5f6ff9369218.json'
# Missing key 'district' in file '../../data/floods-data_manual/2022/01/25/00/00\2022_01_25_00_00_b503d0de4a5f443d8d8dd833b1bd8e57_b503d0de4a5f443d8d8dd833b1bd8e57.json'
# Missing key 'district' in file '../../data/floods-data_manual/2022/01/25/00/00\2022_01_25_00_00_b67017e45fbc4155a28b501bd7ce73ed_b67017e45fbc4155a28b501bd7ce73ed.json'
# Missing key 'district' in file '../../data/floods-data_manual/2022/01/25/00/00\2022_01_25_00_00_b94ecdfbfa69452ab8f80b88c82465a5_b94ecdfbfa69452ab8f80b88c82465a5.json'
# Missing key 'state' in file '../../data/floods-data_manual/2022/01/25/00/00\2022_01_25_00_00_bb11a45e0cbb4d3da2b77b5644fef440_bb11a45e0cbb4d3da2b77b5644fef440.json'
# Missing key 'district' in file '../../data/floods-data_manual/2022/01/25/00/00\2022_01_25_00_00_bcc5c1bf2dc049d29dea7caef088afa3_bcc5c1bf2dc049d29dea7caef088afa3.json'
# Missing key 'district' in file '../../data/floods-data_manual/2022/01/25/00/00\2022_01_25_00_00_bde1b75c51024f0da9c7193cbd21719d_bde1b75c51024f0da9c7193cbd21719d.json'
# Missing key 'state' in file '../../data/floods-data_manual/2022/01/25/00/00\2022_01_25_00_00_bfe965ad328f4d0fba0d9905944053d2_bfe965ad328f4d0fba0d9905944053d2.json'
# Missing key 'district' in file '../../data/floods-data_manual/2022/01/25/00/00\2022_01_25_00_00_c023351781474cc5b7335c113f2e1fb9_c023351781474cc5b7335c113f2e1fb9.json'
# Missing key 'district' in file '../../data/floods-data_manual/2022/01/25/00/00\2022_01_25_00_00_c06991340b82409abb527bfba8e78d8d_c06991340b82409abb527bfba8e78d8d.json'
# Missing key 'state' in file '../../data/floods-data_manual/2022/01/25/00/00\2022_01_25_00_00_c125306e38f14f0d963bc566e9e83031_c125306e38f14f0d963bc566e9e83031.json'
# Missing key 'state' in file '../../data/floods-data_manual/2022/01/25/00/00\2022_01_25_00_00_c1e40740ac2d4c969bdbea1d29a70e3b_c1e40740ac2d4c969bdbea1d29a70e3b.json'
# Missing key 'district' in file '../../data/floods-data_manual/2022/01/25/00/00\2022_01_25_00_00_c1f437d736644a7c8197850c5d357ffd_c1f437d736644a7c8197850c5d357ffd.json'
# Missing key 'publisherName' in file '../../data/floods-data_manual/2022/01/25/00/00\2022_01_25_00_00_c5eb5818bd8045a0b60bd66d1ac6a3b5_c5eb5818bd8045a0b60bd66d1ac6a3b5.json'
# Missing key 'extremeDangerLevel' in file '../../data/floods-data_manual/2022/01/25/00/00\2022_01_25_00_00_c607a6633cb24cc498435d17b28d0509_c607a6633cb24cc498435d17b28d0509.json'
# Missing key 'state' in file '../../data/floods-data_manual/2022/01/25/00/00\2022_01_25_00_00_c7b41d2cd9e44348a2af769e802ae33d_c7b41d2cd9e44348a2af769e802ae33d.json'
# Missing key 'district' in file '../../data/floods-data_manual/2022/01/25/00/00\2022_01_25_00_00_cae810aec3e14948ab8b4314b341b4a8_cae810aec3e14948ab8b4314b341b4a8.json'
# Missing key 'district' in file '../../data/floods-data_manual/2022/01/25/00/00\2022_01_25_00_00_ceeddeefbe5a453a8f57f4382ec9dc44_ceeddeefbe5a453a8f57f4382ec9dc44.json'
# Missing key 'state' in file '../../data/floods-data_manual/2022/01/25/00/00\2022_01_25_00_00_d1f244fc1c0c4cb4a766cf538184bfea_d1f244fc1c0c4cb4a766cf538184bfea.json'
# Missing key 'state' in file '../../data/floods-data_manual/2022/01/25/00/00\2022_01_25_00_00_d2135712d29e4c5788f2fdeaec21dd1d_d2135712d29e4c5788f2fdeaec21dd1d.json'
# Missing key 'district' in file '../../data/floods-data_manual/2022/01/25/00/00\2022_01_25_00_00_d2ca72475c9449be903d7c1666e8865c_d2ca72475c9449be903d7c1666e8865c.json'
# Missing key 'district' in file '../../data/floods-data_manual/2022/01/25/00/00\2022_01_25_00_00_d387bd425c524068b204129e5dacb9d0_d387bd425c524068b204129e5dacb9d0.json'
# Missing key 'district' in file '../../data/floods-data_manual/2022/01/25/00/00\2022_01_25_00_00_d40c24bb8e804956a6818ddccf621d24_d40c24bb8e804956a6818ddccf621d24.json'
# Missing key 'district' in file '../../data/floods-data_manual/2022/01/25/00/00\2022_01_25_00_00_d4f547c15be444828b7f382c6cd60caa_d4f547c15be444828b7f382c6cd60caa.json'
# Missing key 'state' in file '../../data/floods-data_manual/2022/01/25/00/00\2022_01_25_00_00_d6a69e2654974c92bde0c4256bf669e8_d6a69e2654974c92bde0c4256bf669e8.json'
# Missing key 'district' in file '../../data/floods-data_manual/2022/01/25/00/00\2022_01_25_00_00_d75130d2392942d7b5b072e84fdac91d_d75130d2392942d7b5b072e84fdac91d.json'
# Missing key 'state' in file '../../data/floods-data_manual/2022/01/25/00/00\2022_01_25_00_00_d947ed651b554e079bb6c79a8eb049aa_d947ed651b554e079bb6c79a8eb049aa.json'
# Missing key 'district' in file '../../data/floods-data_manual/2022/01/25/00/00\2022_01_25_00_00_dc03a50f75f346cb8e61de04c8ede609_dc03a50f75f346cb8e61de04c8ede609.json'
# Missing key 'district' in file '../../data/floods-data_manual/2022/01/25/00/00\2022_01_25_00_00_dc3fb1bd3b754780968a74c1f03e39fd_dc3fb1bd3b754780968a74c1f03e39fd.json'
# Missing key 'extremeDangerLevel' in file '../../data/floods-data_manual/2022/01/25/00/00\2022_01_25_00_00_dc83affae248485684c96e8f3d984e85_dc83affae248485684c96e8f3d984e85.json'
# Missing key 'state' in file '../../data/floods-data_manual/2022/01/25/00/00\2022_01_25_00_00_deaf0581fa4b42009781ede2feb43255_deaf0581fa4b42009781ede2feb43255.json'
# Missing key 'state' in file '../../data/floods-data_manual/2022/01/25/00/00\2022_01_25_00_00_e074851489f7447f9b07c54e778e2bde_e074851489f7447f9b07c54e778e2bde.json'
# Missing key 'district' in file '../../data/floods-data_manual/2022/01/25/00/00\2022_01_25_00_00_e22a27e9c08744969a7ed62524b34916_e22a27e9c08744969a7ed62524b34916.json'
# Missing key 'district' in file '../../data/floods-data_manual/2022/01/25/00/00\2022_01_25_00_00_e849807ec73d4a0ab0d305c8f20a1e7b_e849807ec73d4a0ab0d305c8f20a1e7b.json'
# Missing key 'district' in file '../../data/floods-data_manual/2022/01/25/00/00\2022_01_25_00_00_e89f574c2a2145ddab605aec7eb25796_e89f574c2a2145ddab605aec7eb25796.json'
# Missing key 'state' in file '../../data/floods-data_manual/2022/01/25/00/00\2022_01_25_00_00_e93219b08daf46df8530ef1a38399e21_e93219b08daf46df8530ef1a38399e21.json'
# Missing key 'district' in file '../../data/floods-data_manual/2022/01/25/00/00\2022_01_25_00_00_ead53945ed324364b13b2030cec8067f_ead53945ed324364b13b2030cec8067f.json'
# Missing key 'district' in file '../../data/floods-data_manual/2022/01/25/00/00\2022_01_25_00_00_ebafea2e957e4f2ea2073441cff3217d_ebafea2e957e4f2ea2073441cff3217d.json'
# Missing key 'state' in file '../../data/floods-data_manual/2022/01/25/00/00\2022_01_25_00_00_ec80b96c0e5149ddb92207835676f578_ec80b96c0e5149ddb92207835676f578.json'
# Missing key 'district' in file '../../data/floods-data_manual/2022/01/25/00/00\2022_01_25_00_00_ee7647961bdd486989c7f16593e0730e_ee7647961bdd486989c7f16593e0730e.json'
# Missing key 'publisherName' in file '../../data/floods-data_manual/2022/01/25/00/00\2022_01_25_00_00_ef7360ed210a42d480e7c344e7011587_ef7360ed210a42d480e7c344e7011587.json'
# Missing key 'state' in file '../../data/floods-data_manual/2022/01/25/00/00\2022_01_25_00_00_f13367bb1e814895a638827341023ffb_f13367bb1e814895a638827341023ffb.json'
# Missing key 'district' in file '../../data/floods-data_manual/2022/01/25/00/00\2022_01_25_00_00_f14a807488894a3593d9f9b34048f50a_f14a807488894a3593d9f9b34048f50a.json'
# Missing key 'district' in file '../../data/floods-data_manual/2022/01/25/00/00\2022_01_25_00_00_f263d4dd56c24500a94646ba323bc938_f263d4dd56c24500a94646ba323bc938.json'
# Missing key 'state' in file '../../data/floods-data_manual/2022/01/25/00/00\2022_01_25_00_00_f27f755e36b446839cc15471b43dea4f_f27f755e36b446839cc15471b43dea4f.json'
# Missing key 'district' in file '../../data/floods-data_manual/2022/01/25/00/00\2022_01_25_00_00_f3c2d8fe73534d45a60df92dfe3440b1_f3c2d8fe73534d45a60df92dfe3440b1.json'
# Missing key 'publisherName' in file '../../data/floods-data_manual/2022/01/25/00/00\2022_01_25_00_00_f791cff3440f4703a2a98a87969d8f65_f791cff3440f4703a2a98a87969d8f65.json'
# Missing key 'state' in file '../../data/floods-data_manual/2022/01/25/00/00\2022_01_25_00_00_f8243462c55845cd9a8ec4a9e8227f18_f8243462c55845cd9a8ec4a9e8227f18.json'
# Missing key 'state' in file '../../data/floods-data_manual/2022/01/25/00/00\2022_01_25_00_00_fa0f81affce14a1da762dd0a5907bbbf_fa0f81affce14a1da762dd0a5907bbbf.json'
# Missing key 'state' in file '../../data/floods-data_manual/2022/01/25/00/00\2022_01_25_00_00_fae8dd811580400dbccc4b533415c2e2_fae8dd811580400dbccc4b533415c2e2.json'
# Missing key 'district' in file '../../data/floods-data_manual/2022/01/25/00/00\2022_01_25_00_00_fca78f9e1e934b54b1384ae7c33cec25_fca78f9e1e934b54b1384ae7c33cec25.json'
# Missing key 'publisherName' in file '../../data/floods-data_manual/2022/01/25/00/00\2022_01_25_00_00_fdb1d0fde1924c28a7ae984e70ace422_fdb1d0fde1924c28a7ae984e70ace422.json'
# Missing key 'state' in file '../../data/floods-data_manual/2022/01/25/00/00\2022_01_25_00_00_fde9ea2fad954e83874d230f3225bcdf_fde9ea2fad954e83874d230f3225bcdf.json'

# %%
df_manual_data = tidy_up_dataframe(df_manual_data)
# Out:
# object
# object
# object
# object
# object
# object
# float64
# float64
# float64
# datetime64[ns]
# bool

# %%
print(df_manual_data.dtypes)
# Out:
# district                       object
# gaugeStationName               object
# stationId                      object
# publisherName                  object
# river                          object
# state                          object
# warningLevel                  float64
# dangerLevel                   float64
# extremeDangerLevel            float64
# expirationTimestamp    datetime64[ns]
# hasFlooding                      bool
# dtype: object

# %%
df_manual_data.head(3)
# Out:
#                        district gaugeStationName   stationId  \
# DateTime
# 2022-01-25 01:24:11   Dibrugarh        Dillighat  014-UBDDIB
# 2022-01-25 01:24:11      Mulugu     Eturunagaram  015-LGDHYD
# 2022-01-25 01:24:11  Mayurbhanj         Baripada  004-ERDBWN
#
#                                  publisherName                  river  \
# DateTime
# 2022-01-25 01:24:11            B&BBO, Shillong  Brahmaputra /  Desang
# 2022-01-25 01:24:11            KGBO, Hyderabad               Godavari
# 2022-01-25 01:24:11  Mahanadi & Eastern Rivers            Burhabalang
#
#                               state  warningLevel  dangerLevel  \
# DateTime
# 2022-01-25 01:24:11           Assam        128.00       129.00
# 2022-01-25 01:24:11  Andhra Pradesh         73.32        75.82
# 2022-01-25 01:24:11          Orissa         29.70        30.92
#
#                      extremeDangerLevel expirationTimestamp  hasFlooding
# DateTime
# 2022-01-25 01:24:11              129.65 2022-01-27 01:24:11        False
# 2022-01-25 01:24:11               77.66 2022-01-27 01:24:11        False
# 2022-01-25 01:24:11               34.82 2022-01-27 01:24:11        False

# %%
df_manual_data.tail(3)
# Out:
#                             district gaugeStationName      stationId  \
# DateTime
# 2022-01-25 01:28:10          Sitapur     Batpurwaghat    006-mgd2lkn
# 2022-01-25 01:28:29  Purba Champaran           Chatia    010-mgd4ptn
# 2022-01-25 01:28:46      Kanyakumari         Ashramam  023-SWRDKOCHI
#
#                              publisherName           river          state  \
# DateTime
# 2022-01-25 01:28:10          UGBO, Lucknow   Ganga / Gomti  Uttar Pradesh
# 2022-01-25 01:28:29             LGBO Patna  Ganga / Gandak          Bihar
# 2022-01-25 01:28:46  C&SRO, CWC Coimbatore        Pazhayar      Tamilnadu
#
#                      warningLevel  dangerLevel  extremeDangerLevel  \
# DateTime
# 2022-01-25 01:28:10        113.30       114.30              115.55
# 2022-01-25 01:28:29         68.15        69.15               70.04
# 2022-01-25 01:28:46          4.50         6.00                7.10
#
#                     expirationTimestamp  hasFlooding
# DateTime
# 2022-01-25 01:28:10 2022-01-27 01:28:10        False
# 2022-01-25 01:28:29 2022-01-27 01:28:29        False
# 2022-01-25 01:28:46 2022-01-27 01:28:46        False

# %% [markdown]
# To get to know the spatial coverage of the data, we make an overview of all the districts, rivers, and states present in the data by ...
#
# Conclusion: These are Indian data, not African. Adding coordinates and all will thus come later, including mapping.

# %%
def get_unique_values(df, column_name):
    """
    Returns a list of unique values in the column

    :param df: DataFrame
    :param column_name: Name of the column
    :return: List of unique values
    """
    unique_values = df[column_name].unique().tolist()
    return unique_values


def print_list(l: List) -> None:
    """
    Prints a list of items

    :param l: List of items
    """
    for i in l:
        print(i)


def print_unique_col_vals(df, col):
    """
    Prints unique values in a column

    :param df: DataFrame
    :param col: Column name
    """
    print_list(sorted(get_unique_values(df, col)))

# %%
print_unique_col_vals(df_manual_data, 'district')
# Out:
# Adilabad
# Agra
# Ahmadnagar
# Ahmedabad
# Almora
# Anantnag
# Araria
# Auraiya
# Ayodhya
# Bahraich
# Baksa
# Balasore
# Baleshwar
# Ballia
# Balrampur
# Barabanki
# Baramula
# Barpeta
# Bastar
# Basti
# Bhadradri
# Bhadrak
# Bhagalpur
# Bhandara
# Bharuch
# Bhupalpally
# Bijapur
# Birbhum
# Budaun
# Buldana
# Buxar
# Cachar
# Chamoli
# Chandrapur
# Cuttack
# Dadra And Nagar Haveli
# Dakshin Kannada
# Darbhanga
# Datia
# Dehradun
# Deoria
# Dhalai
# Dholpur
# Dhubri
# Dhule
# Dibrugarh
# East Godavari
# East Siang
# Ernakulam
# Erode
# Etawah
# Farrukhabad
# Gajapati
# Ganjam
# Gaya
# Ghaziabad
# Ghazipur
# Goalpara
# Golaghat
# Gonda
# Gopalganj
# Gorakhpur
# Hailakandi
# Hamirpur
# Haridwar
# Hoshangabad
# Idukki
# Jagatsinghapur
# Jajapur
# Jalaun
# Jalpaiguri
# Jaunpur
# Jehanabad
# Jhansi
# Jorhat
# Kamrup
# Kannur
# Kanpur Dehat
# Kanpur Nagar
# Kanyakumari
# Karnal
# Karur
# Katihar
# Kendujhar
# Khagaria
# Khammam
# Kheda
# Kheri
# Kishanganj
# Kochbihar
# Kokrajhar
# Kolhapur
# Kollam
# Kota
# Kottayam
# Kozhikode
# Krishna
# Kurnool
# Kushinagar
# Lakhimpur
# Lohit
# Lucknow
# Madhubani
# Maharajganj
# Malappuram
# Mandla
# Marigaon
# Mathura
# Mayurbhanj
# Medinipur
# Mirzapur
# Moradabad
# Mulugu
# Munger
# Muzaffarnagar
# Muzaffarpur
# Nadia
# Nagaon
# Nalbari
# Nanded
# Narmada
# Nashik
# Nawada
# North
# North Tripura
# Palakkad
# Palamau
# Parbhani
# Pashchim Champaran
# Pathanamthitta
# Patna
# Pauri Garhwal
# Praygraj
# Pune
# Purba Champaran
# Purbi Singhbhum
# Puri
# Purnia
# Raibareli
# Raigad
# Rajgarh
# Ratnagiri
# Rayagada
# Rohtas
# Sahebganj
# Samastipur
# Sangli
# Satara
# Sepahijala
# Shahjhanpur
# Shrawasti
# Sibsagar
# Siddharth Nagar
# Sidhi
# Sirmaur
# Sirohi
# Sitamarhi
# Sitapur
# Siwan
# Solapur
# Sonbhadra
# Sonitpur
# South Tripura
# South West
# Srikakulam
# Srinagar
# Supaul
# Surat
# Thane
# Thiruvananthapuram
# Thrissur
# Tinsukia
# Tiruchirappalli
# Udupi
# Uttara Kannada
# Uttarkashi
# Vaishali
# Valsad
# Varanasi
# West District
# West Tripura

# %%
print_unique_col_vals(df_manual_data, 'state')
# Out:
# Andhra Pradesh
# Arunachal Pradesh
# Assam
# Bihar
# Chhattishgarh
# D.&Nh
# Delhi
# Gujarat
# Haryana
# Himachal Pradesh
# Jammu & Kashmir
# Jharkhand
# Karnataka
# Kerala
# Madhya Pradesh
# Maharashtra
# Odisha
# Orissa
# Rajasthan
# Tamilnadu
# Tripura
# Uttar Pradesh
# Uttarakhand
# West Bengal
# West Sikkim

# %%
print_unique_col_vals(df_manual_data, 'river')
# Out:
# Aghanashini
# Baitarni
# Banas
# Barak
# Barak / Katakhal
# Bav
# Bhagirathi / Ajoy
# Bharathapuzha
# Bhogeswari
# Brahmani
# Brahmaputra
# Brahmaputra /  Brahmaputra
# Brahmaputra /  Buridehing
# Brahmaputra /  Desang
# Brahmaputra /  Dhansari(South)
# Brahmaputra /  Dhansiri(South)
# Brahmaputra /  Dikhow
# Brahmaputra /  Jiabharali
# Brahmaputra /  Kopili
# Brahmaputra /  Lohit
# Brahmaputra /  Noa-Dehing
# Brahmaputra /  Ranganadi
# Brahmaputra /  Siang
# Brahmaputra /  Subansiri
# Brahmaputra /  Teesta
# Brahmaputra /  Torsa
# Brahmaputra / Beki
# Brahmaputra / Gaurang
# Brahmaputra / Jaldhaka
# Brahmaputra / Manas
# Brahmaputra / Pagladiya
# Brahmaputra / Puthimari
# Brahmaputra / Sonkosh
# Brahmaputra / Torsa / Raidak-I
# Burhabalang
# Cauvery
# Cauvery / Amaravathi
# Cauvery / Bhavani
# Chaliyar
# Chambal
# Damanganga
# Damanganga / Wagh
# Ganga
# Ganga / Alaknanda
# Ganga / Alaknanda / Pinder
# Ganga / Bhagirath
# Ganga / Burhi Gandak
# Ganga / Gandak
# Ganga / Ghaghra
# Ganga / Ghaghra / Kwano
# Ganga / Ghaghra / Little Gandak
# Ganga / Ghaghra / Rapti
# Ganga / Ghaghra / Rapti / Burthi Rapti
# Ganga / Ghaghra / Rapti / Kunhara
# Ganga / Ghaghra / Rapti / Rohin
# Ganga / Ghaghra / Sarju
# Ganga / Ghaghra / Sarju(Babai)
# Ganga / Ghaghra / Saryu
# Ganga / Ghaghra / Sharda
# Ganga / Gomti
# Ganga / Gomti / Sai
# Ganga / Kiul
# Ganga / Kiul / Harohar / Phalgu
# Ganga / Kosi
# Ganga / Kosi / Bagmati
# Ganga / Kosi / Bagmati / Adhwara
# Ganga / Kosi / Kamla-Balan
# Ganga / Mahananda
# Ganga / Mahananda / Parman
# Ganga / Mayurakshi
# Ganga / Punpun
# Ganga / Ramganga
# Ganga / Sone
# Ganga / Sone / North Koel
# Ganga / Yamuna
# Ganga / Yamuna / Betwa
# Ganga / Yamuna / Betwa / Dhasan
# Ganga / Yamuna / Chambal
# Ganga / Yamuna / Ken
# Ganga / Yamuna / Sahibi
# Ganga / Yamuna / Sind
# Godavari
# Godavari / Indravati
# Godavari / Pranhita / Wainganga
# Godavari / Pranhita / Wainganga / Wainganga
# Godavari / Pranhita / Wardha
# Gurupur
# Haladi
# Hoogly / Kangsabati
# Jalaka
# Jhelum
# Kadalundi
# Kallada
# Krishna
# Krishna / Bhima
# Krishna / Koyna
# Krishna / Panchganga
# Krishna / Tungabhadra
# Krishna / Varna
# Kuttyadi
# Mahanadi
# Mahanadi /  Kushabhadr
# Mahanadi / Devi
# Mahi
# Meenachi
# Meghna /  Burima
# Meghna /  Haora
# Meghna /  Juri
# Meghna /  Khowai
# Meghna /  Muhari
# Muvattupuzha
# Nagavali
# Narmada
# Nethravathi
# Pamba
# Pazhayar
# Periyar
# Rushikulya
# Sabari
# Sabarmati
# Savitri
# Subernarekha
# Swarna / Yennehole
# Tapi
# Tapi / Purna
# Teesta / Rangit River
# Thambraparni
# Tungabhadra
# Ulhas
# Valapatnam
# Vamanapuram
# Vamsadhar
# Vamsadhara

# %%
print_unique_col_vals(df_manual_data, 'gaugeStationName')
# Out:
# Abu Road
# Addoor
# Agra (J.B.)
# Ahirwalia (Seasonal)
# Akhuapada
# Alipingal
# Anandapur
# Ankinghat
# Anna Purna Ghat
# Arangaly
# Araria (Seasonal)
# Arjunwad (Seasonal)
# Ashramam
# Auralya
# Avanigadda
# Ayilam
# Ayodhya
# B.K. Ghat
# Badar Pur Ghat
# Badatighat
# Badlapur
# Ballia
# Balrampur
# Baltara
# Bamni
# Banda
# Bani
# Bansi
# Bantwal
# Baripada
# Basti
# Basua
# Batpurwaghat
# Beki Road Bridge
# Belonia
# Benibad
# Bhadrachalam
# Bhagalpur
# Bhandara
# Bharuch
# Bhikiasen
# Bihubar
# Birdghat
# Burhanpur
# Buxar
# Chandradeepghat
# Chatia
# Chenimari
# Chhapra (Seasonal)
# Chhatang Allahabad
# Chillaghat
# Chinturu
# Chopan
# Chouldhowaghat
# Colonelganj
# Dabri
# Dalmau
# Daltenganj
# Darauli
# Delhi Rly Bridge
# Deongaon Bridge
# Dhansa
# Dharamtul
# Dheng Bridge
# Dhengraghat
# Dholabazar
# Dholpur
# Dhond
# Dhubri
# Dibrugarh
# Dighaghat (Seasonal)
# Dillighat
# Domohani
# Dowlaiswaram
# Dumariaghat
# Dummugudem
# Ekmighat
# Elginbridge
# Etawah
# Eturunagaram
# Fatehgarh
# Gajaraia
# Gandhighat
# Gangahed W / L Station
# Gangpur Siswan (Seasonal)
# Garhamukteshwar
# Garrauli
# Garudeshwar
# Gaya
# Ghaighat
# Ghazipur
# Gheropara
# Ghugumari
# Gidhade
# Goalpara
# Golaghat
# Golokganj
# Govindapur
# Gunupur
# Guwahati
# Hajipur (Seasonal)
# Haladi
# Hamirpur
# Haora
# Hardwar
# Hasimara
# Hathidah
# Hayaghat
# Hetimpur
# Hoshangabad
# Indrapuri
# Jagdalpur
# Jagibhakatgaon
# Jai Nagar
# Jamshedpur
# Jamsholaghat
# Japla
# Jaunpur
# Jenapur
# Jhanjharpur
# Jhawa (Seasonal)
# Jiabharali    Nt Road          X-Ing
# Joshimath
# Kachlabridge
# Kadirganj
# Kahalgaon
# Kakardhari
# Kalampur
# Kaleswaram
# Kallooppara
# Kalpi
# Kampur
# Kamtaul
# Kanpur
# Karad
# Karanprayag
# Karathodu
# Karnal
# Kashinagar
# Khadda
# Khagaria
# Khowai
# Kidangoor
# Kinjer (Seasonal)
# Kodumudi
# Koelwar
# Kokrajhar
# Kopergaon
# Kota City
# Kuldah Bridge
# Kumbidi
# Kunavaram
# Kuniyil
# Kurnool
# Kursela
# Kuttyadi
# Kuzhithurai
# Lakhisarai
# Lalbegiaghat
# Lucknow
# Mahad
# Malakkara
# Manas Nh Crossing
# Mandla
# Maner (Seasonal)
# Mantralayam
# Mathabhanga
# Mathanguri
# Mathani Road Bridge
# Mathura (Prayagghat)
# Matizuri
# Mawi
# Mekhliganj
# Mirzapur
# Mohammad Ganj
# Mohanpur
# Moradabad
# Munger
# Musiri
# Naharkatia
# Nallammaranpatty
# Namsai
# Nanded
# Nanglamoraghat
# Nanipalson
# Naraj
# Narasingpur
# Narayanpur (Seasonal)
# Nasik
# Nautghat
# Neamatighat
# Neeleswaram
# Neemsar
# Nh-31
# Nimapara
# Nivali
# Numaligarh
# Nutanbazar
# Ozerkheda
# Pagladiya N.T.Road X-Ing
# Paliakalan
# Paonata
# Passighat
# Pattazhy
# Pauni
# Pen
# Perumannu
# Phaphamau
# Pudur
# Pulamanthole
# Purushottampu
# Puthimari N.H X-Ing
# Raibareli
# Rajghat
# Ram Munshi Bagh
# Ramamangala
# Ranganadi      Nt-Road Crossing
# Rewaghat
# Rishikesh
# Rosera
# Rothak
# Runisaidpur
# Safapora
# Sahibganj (Seasonal)
# Salempur
# Samastipur
# Samdoli (Seasonal)
# Sangam
# Santeguli
# Sarangkheda
# Savandapur
# Seondha
# Shahijina
# Shardanagar
# Sikanderpur
# Silvassa
# Sirpur
# Sivasagar
# Sonbarsha
# Sorada
# Srikakulam
# Srinagar
# Sripalpur
# Subhash Bridge
# Surat(Seasonal)
# Taibpur
# Terwad (Seasonal)
# Tezpur
# Thumpamon
# Trimohinighat
# Triveni
# Tufanganj
# Turtipar
# Uskabazar
# Uttarkashi
# Vandiperiyar
# Vapi
# Varanasi
# Wanakbori
# Warunjli
# Yennehole
# Yerli
